# %% [markdown]
# # Load Package

# %%
import pandas as pd
import numpy as np
import os
import networkx as nx
from node2vec import Node2Vec
import matplotlib.pyplot as plt

# %%
print (os.getcwd())
os.chdir('D:/OneDrive/ASU/2021 Spring/Applied Project/ASU_Applied_Project_2021/Data')
print (os.getcwd())
# Out:
# C:\Users\Jinhang Jiang
# D:\OneDrive\ASU\2021 Spring\Applied Project\ASU_Applied_Project_2021\Data

# %% [markdown]
# # Load Data and Explore

# %%
data = pd.read_csv("NetworkAnalysis1.csv")

# %%
data.head(6)
# Out:
#      Celebrity       Usernames
# 0  kerwinfrost  vincenthoobyar
# 1  kerwinfrost          ludwek
# 2  kerwinfrost         A_G_X10
# 3  kerwinfrost        CartHard
# 4  kerwinfrost          jothvm
# 5  kerwinfrost     saucyboy210

# %%
print(*data.Celebrity.unique(),sep="\n")
# Out:
# kerwinfrost
# James Bond
# beyonce
# ZoeSaldana
# karlie kloss
# Yara Shahidi
# naeun
# Pharrell Williams
# Adriene Mishler
# BlackPink
# Ninjas Hyper
# BadBunny

# %%
data.shape
# Out:
# (9764, 2)

# %%
print("Number of Celebrities: %0.0f" %len(data.Celebrity.unique()))
print("Number of Users: %0.0f" %len(data.Usernames.unique()))
# Out:
# Number of Celebrities: 12
# Number of Users: 1505

# %%
print("The percentage of unique values: %0.4f" %(len(data.Usernames.unique())/len(data.Usernames)))
# Out:
# The percentage of unique values: 0.1541

# %% [markdown]
# # Generate Adjacency Matrix

# %%
#Create matrix
matrix = pd.get_dummies(data.set_index('Usernames')['Celebrity'].astype(str)).max(level=0).sort_index()

# %%
matrix.iloc[0:5,0:5]
# Out:
#                 Adriene Mishler  BadBunny  BlackPink  James Bond  Ninjas Hyper
# Usernames
# -Fashion-News-                1         1          1           0             1
# -SODANK-                      0         1          0           0             0
# -Sportswear-                  1         1          1           0             1
# -en-                          1         1          1           0             1
# 12e64m3                       1         1          1           0             1

# %%
cel_matrix = np.asmatrix(matrix)
cel_matrix_transpose = cel_matrix.transpose()
final_matrix = cel_matrix_transpose.dot(cel_matrix)

network_table = pd.DataFrame(final_matrix)
print(network_table.iloc[0:5,0:5])
print(network_table.shape)
# Out:
#     0    1    2  3    4
# 0  11   11   11  4   11
# 1  11  225  166  4   46
# 2  11  166  166  4  166
# 3   4    4    4  4    4
# 4  11   46  166  4   46
# (12, 12)

# %%
## append index name
Celebrity = list(data.Celebrity.unique())
Celebrity.sort()

network_table.index = Celebrity
network_table.columns = Celebrity
network_table
# Out:
#                    Adriene Mishler  BadBunny  BlackPink  James Bond  \
# Adriene Mishler                 11        11         11           4
# BadBunny                        11       225        166           4
# BlackPink                       11       166        166           4
# James Bond                       4         4          4           4
# Ninjas Hyper                    11        46        166           4
# Pharrell Williams              255       255        255           4
# Yara Shahidi                    36        36         36           4
# ZoeSaldana                      93        93         93           4
# beyonce                        172       172        172           4
# karlie kloss                   186       186        186           4
# kerwinfrost                     30        30         30          30
# naeun                           92        92         92           4
#
#                    Ninjas Hyper  Pharrell Williams  Yara Shahidi  ZoeSaldana  \
# Adriene Mishler              11                255            36          93
# BadBunny                     46                255            36          93
# BlackPink                   166                255            36          93
# James Bond                    4                  4             4           4
# Ninjas Hyper                 46                255            36          93
# Pharrell Williams           255                255            36          93
# Yara Shahidi                 36                 36            36          93
# ZoeSaldana                   93                 93            93          93
# beyonce                     172                172           172         172
# karlie kloss                186                186           186          93
# kerwinfrost                  30                 30            30          30
# naeun                        92                 92            36          93
#
#                    beyonce  karlie kloss  kerwinfrost  naeun
# Adriene Mishler        172           186           30     92
# BadBunny               172           186           30     92
# BlackPink              172           186           30     92
# James Bond               4             4           30      4
# Ninjas Hyper           172           186           30     92
# Pharrell Williams      172           186           30     92
# Yara Shahidi           172           186           30     36
# ZoeSaldana             172            93           30     93
# beyonce                172           172           30    172
# karlie kloss           172           186           30    186
# kerwinfrost             30            30           30     30
# naeun                  172           186           30     92

# %%
#matrix.to_csv('frequency_matrix1.csv')
#network_table.to_csv('network_table1.csv')

# %% [markdown]
# # Fit NetworkX

# %%
#network_table = pd.read_csv('network_table1.csv', index_col=0)

# %%
network_table.head(3)
# Out:
#                  Adriene Mishler  BadBunny  BlackPink  James Bond  \
# Adriene Mishler               11        11         11           4
# BadBunny                      11       225        166           4
# BlackPink                     11       166        166           4
#
#                  Ninjas Hyper  Pharrell Williams  Yara Shahidi  ZoeSaldana  \
# Adriene Mishler            11                255            36          93
# BadBunny                   46                255            36          93
# BlackPink                 166                255            36          93
#
#                  beyonce  karlie kloss  kerwinfrost  naeun
# Adriene Mishler      172           186           30     92
# BadBunny             172           186           30     92
# BlackPink            172           186           30     92

# %%
#pip install --upgrade networkx
# Out:
# Collecting networkx
#   Downloading https://files.pythonhosted.org/packages/9b/cd/dc52755d30ba41c60243235460961fc28022e5b6731f16c268667625baea/networkx-2.5-py3-none-any.whl (1.6MB)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in d:\1dataanalytics\python\anaconda3\lib\site-packages (from networkx) (4.4.0)
# Installing collected packages: networkx
#   Found existing installation: networkx 2.3
#     Uninstalling networkx-2.3:
#       Successfully uninstalled networkx-2.3
# Successfully installed networkx-2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
graph=nx.from_numpy_matrix(np.matrix(network_table))

# %%
node2vec = Node2Vec(graph, dimensions=25, walk_length=10, num_walks=300, workers=4)
model = node2vec.fit(window=10, min_count=1)
# Out:
# Computing transition probabilities: 100%|████████████████████████████████████████████| 12/12 [00:00<00:00, 2005.72it/s]

# %%
model.wv.save_word2vec_format('embedding')

# %%
vocab, vectors = model.wv.vocab, model.wv.vectors

# get node name and embedding vector index.
name_index = np.array([(v[0], v[1].index) for v in vocab.items()])

# init dataframe using embedding vectors and set index as node name
df =  pd.DataFrame(vectors[name_index[:,1].astype(int)])
df.index = name_index[:, 0]

# %%
df = df.sort_index(ascending=True)
df
# Out:
#           0         1         2         3         4         5         6   \
# 0  -0.147744 -0.044176  0.065672 -0.083068 -0.294284  0.342981  0.184983
# 1  -0.163335 -0.066436  0.052841 -0.114052 -0.319886  0.359776  0.173201
# 10 -0.168566 -0.035804  0.098199 -0.129922 -0.360240  0.346373  0.188753
# 11 -0.149148 -0.059372  0.066437 -0.085810 -0.300096  0.354894  0.169167
# 2  -0.159323 -0.042151  0.084771 -0.099135 -0.318472  0.362776  0.176587
# 3  -0.180591 -0.036817  0.059722 -0.131494 -0.343669  0.364086  0.160926
# 4  -0.142373 -0.066504  0.063518 -0.087927 -0.326281  0.340159  0.167958
# 5  -0.137536 -0.075668  0.055149 -0.105118 -0.317359  0.348143  0.163557
# 6  -0.120312 -0.063577  0.092431 -0.119435 -0.311107  0.323934  0.184652
# 7  -0.147220 -0.047069  0.068712 -0.114014 -0.333816  0.333292  0.183427
# 8  -0.167371 -0.071309  0.053822 -0.086711 -0.287004  0.363799  0.163352
# 9  -0.168127 -0.057711  0.071768 -0.089614 -0.323656  0.364120  0.159911
#
#           7         8         9   ...        15        16        17        18  \
# 0  -0.237668  0.223541  0.081853  ... -0.161684  0.379380 -0.005959  0.497341
# 1  -0.256655  0.205670  0.079700  ... -0.160427  0.385589  0.018726  0.504790
# 10 -0.252003  0.193143  0.093038  ... -0.155007  0.396961  0.019826  0.501776
# 11 -0.266838  0.240197  0.083486  ... -0.180132  0.362748 -0.004909  0.514344
# 2  -0.273824  0.238587  0.097037  ... -0.156165  0.377907  0.022927  0.511601
# 3  -0.249468  0.192522  0.103723  ... -0.163323  0.381578  0.017135  0.518914
# 4  -0.248896  0.206247  0.102187  ... -0.165456  0.372962 -0.009984  0.506581
# 5  -0.249705  0.239935  0.107772  ... -0.161702  0.365878  0.011791  0.501865
# 6  -0.245627  0.242171  0.104827  ... -0.135402  0.354035  0.008026  0.503384
# 7  -0.263661  0.252079  0.091213  ... -0.145265  0.371257 -0.013080  0.505189
# 8  -0.263727  0.207472  0.091727  ... -0.186760  0.390325  0.003572  0.498527
# 9  -0.267953  0.231975  0.111026  ... -0.175510  0.380983  0.017917  0.486391
#
#           19        20        21        22        23        24
# 0  -0.427108 -0.220243  0.023671 -0.278857 -0.674725  0.122246
# 1  -0.437128 -0.211555  0.047788 -0.275712 -0.660629  0.136803
# 10 -0.468067 -0.282426  0.058031 -0.310693 -0.749540  0.114207
# 11 -0.436735 -0.244049  0.041285 -0.267606 -0.668746  0.117431
# 2  -0.418118 -0.207591  0.063781 -0.287111 -0.650371  0.134036
# 3  -0.474209 -0.272068  0.066084 -0.279853 -0.731425  0.090622
# 4  -0.414640 -0.239577  0.061644 -0.294533 -0.663465  0.144747
# 5  -0.418214 -0.233691  0.050897 -0.269465 -0.649101  0.102994
# 6  -0.439549 -0.232736  0.036261 -0.270565 -0.680053  0.105144
# 7  -0.411252 -0.251979  0.031720 -0.286749 -0.681496  0.117579
# 8  -0.416434 -0.223447  0.067984 -0.284087 -0.667711  0.130860
# 9  -0.417701 -0.223385  0.043602 -0.288271 -0.672777  0.099431
#
# [12 rows x 25 columns]

# %%
celebrity_names = ['Adriene Mishler','BadBunny','kerwinfrost','naeun',
 'BlackPink','James Bond','Ninjas Hyper','Pharrell Williams','Yara Shahidi',
 'ZoeSaldana','beyonce','karlie kloss']

# %%
df.index = celebrity_names

# %%
df
# Out:
#                          0         1         2         3         4         5   \
# Adriene Mishler   -0.147744 -0.044176  0.065672 -0.083068 -0.294284  0.342981
# BadBunny          -0.163335 -0.066436  0.052841 -0.114052 -0.319886  0.359776
# kerwinfrost       -0.168566 -0.035804  0.098199 -0.129922 -0.360240  0.346373
# naeun             -0.149148 -0.059372  0.066437 -0.085810 -0.300096  0.354894
# BlackPink         -0.159323 -0.042151  0.084771 -0.099135 -0.318472  0.362776
# James Bond        -0.180591 -0.036817  0.059722 -0.131494 -0.343669  0.364086
# Ninjas Hyper      -0.142373 -0.066504  0.063518 -0.087927 -0.326281  0.340159
# Pharrell Williams -0.137536 -0.075668  0.055149 -0.105118 -0.317359  0.348143
# Yara Shahidi      -0.120312 -0.063577  0.092431 -0.119435 -0.311107  0.323934
# ZoeSaldana        -0.147220 -0.047069  0.068712 -0.114014 -0.333816  0.333292
# beyonce           -0.167371 -0.071309  0.053822 -0.086711 -0.287004  0.363799
# karlie kloss      -0.168127 -0.057711  0.071768 -0.089614 -0.323656  0.364120
#
#                          6         7         8         9   ...        15  \
# Adriene Mishler    0.184983 -0.237668  0.223541  0.081853  ... -0.161684
# BadBunny           0.173201 -0.256655  0.205670  0.079700  ... -0.160427
# kerwinfrost        0.188753 -0.252003  0.193143  0.093038  ... -0.155007
# naeun              0.169167 -0.266838  0.240197  0.083486  ... -0.180132
# BlackPink          0.176587 -0.273824  0.238587  0.097037  ... -0.156165
# James Bond         0.160926 -0.249468  0.192522  0.103723  ... -0.163323
# Ninjas Hyper       0.167958 -0.248896  0.206247  0.102187  ... -0.165456
# Pharrell Williams  0.163557 -0.249705  0.239935  0.107772  ... -0.161702
# Yara Shahidi       0.184652 -0.245627  0.242171  0.104827  ... -0.135402
# ZoeSaldana         0.183427 -0.263661  0.252079  0.091213  ... -0.145265
# beyonce            0.163352 -0.263727  0.207472  0.091727  ... -0.186760
# karlie kloss       0.159911 -0.267953  0.231975  0.111026  ... -0.175510
#
#                          16        17        18        19        20        21  \
# Adriene Mishler    0.379380 -0.005959  0.497341 -0.427108 -0.220243  0.023671
# BadBunny           0.385589  0.018726  0.504790 -0.437128 -0.211555  0.047788
# kerwinfrost        0.396961  0.019826  0.501776 -0.468067 -0.282426  0.058031
# naeun              0.362748 -0.004909  0.514344 -0.436735 -0.244049  0.041285
# BlackPink          0.377907  0.022927  0.511601 -0.418118 -0.207591  0.063781
# James Bond         0.381578  0.017135  0.518914 -0.474209 -0.272068  0.066084
# Ninjas Hyper       0.372962 -0.009984  0.506581 -0.414640 -0.239577  0.061644
# Pharrell Williams  0.365878  0.011791  0.501865 -0.418214 -0.233691  0.050897
# Yara Shahidi       0.354035  0.008026  0.503384 -0.439549 -0.232736  0.036261
# ZoeSaldana         0.371257 -0.013080  0.505189 -0.411252 -0.251979  0.031720
# beyonce            0.390325  0.003572  0.498527 -0.416434 -0.223447  0.067984
# karlie kloss       0.380983  0.017917  0.486391 -0.417701 -0.223385  0.043602
#
#                          22        23        24
# Adriene Mishler   -0.278857 -0.674725  0.122246
# BadBunny          -0.275712 -0.660629  0.136803
# kerwinfrost       -0.310693 -0.749540  0.114207
# naeun             -0.267606 -0.668746  0.117431
# BlackPink         -0.287111 -0.650371  0.134036
# James Bond        -0.279853 -0.731425  0.090622
# Ninjas Hyper      -0.294533 -0.663465  0.144747
# Pharrell Williams -0.269465 -0.649101  0.102994
# Yara Shahidi      -0.270565 -0.680053  0.105144
# ZoeSaldana        -0.286749 -0.681496  0.117579
# beyonce           -0.284087 -0.667711  0.130860
# karlie kloss      -0.288271 -0.672777  0.099431
#
# [12 rows x 25 columns]
